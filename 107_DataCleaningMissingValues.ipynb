# %% [markdown]
# In this assignment, you are going to use a dataset related to the US education system. Please download the (dataset) from Kaggle. You are going to use states_all.csv within this dataset.
#
#
#
#
#
# This time, fill in the missing values by interpolating.
#
# Compare your answers on the second, third and fourth questions. Do you notice a meaningful difference?

# %%
import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings('ignore')
df = pd.read_csv('data/datasets_95317_1078789_states_all.csv',  low_memory=False)

# %%
print("before: ",df.AVG_MATH_4_SCORE.mean())
df.AVG_MATH_4_SCORE.interpolate(method ='linear', limit_direction ='forward',inplace=True)
print("after: ",df.AVG_MATH_4_SCORE.mean())
# Out:
# before:  236.32743362831857
# after:  232.91982507288625

# %%
df.head(15)
# Out:
#                   PRIMARY_KEY                 STATE  YEAR  ENROLL  \
# 0                1992_ALABAMA               ALABAMA  1992     NaN
# 1                 1992_ALASKA                ALASKA  1992     NaN
# 2                1992_ARIZONA               ARIZONA  1992     NaN
# 3               1992_ARKANSAS              ARKANSAS  1992     NaN
# 4             1992_CALIFORNIA            CALIFORNIA  1992     NaN
# 5               1992_COLORADO              COLORADO  1992     NaN
# 6            1992_CONNECTICUT           CONNECTICUT  1992     NaN
# 7               1992_DELAWARE              DELAWARE  1992     NaN
# 8   1992_DISTRICT_OF_COLUMBIA  DISTRICT_OF_COLUMBIA  1992     NaN
# 9                1992_FLORIDA               FLORIDA  1992     NaN
# 10               1992_GEORGIA               GEORGIA  1992     NaN
# 11                1992_HAWAII                HAWAII  1992     NaN
# 12                 1992_IDAHO                 IDAHO  1992     NaN
# ...

# %% [markdown]
# ## - Find the types of variables in the dataset and the missing (null) ratio of each variable.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1715 entries, 0 to 1714
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   PRIMARY_KEY                   1715 non-null   object
#  1   STATE                         1715 non-null   object
#  2   YEAR                          1715 non-null   int64
#  3   ENROLL                        1224 non-null   float64
#  4   TOTAL_REVENUE                 1275 non-null   float64
#  5   FEDERAL_REVENUE               1275 non-null   float64
#  6   STATE_REVENUE                 1275 non-null   float64
#  7   LOCAL_REVENUE                 1275 non-null   float64
#  8   TOTAL_EXPENDITURE             1275 non-null   float64
#  9   INSTRUCTION_EXPENDITURE       1275 non-null   float64
#  10  SUPPORT_SERVICES_EXPENDITURE  1275 non-null   float64
#  11  OTHER_EXPENDITURE             1224 non-null   float64
# ...

# %%
df.isnull().sum()*100/df.shape[0]
# Out:
# PRIMARY_KEY                      0.000000
# STATE                            0.000000
# YEAR                             0.000000
# ENROLL                          28.629738
# TOTAL_REVENUE                   25.655977
# FEDERAL_REVENUE                 25.655977
# STATE_REVENUE                   25.655977
# LOCAL_REVENUE                   25.655977
# TOTAL_EXPENDITURE               25.655977
# INSTRUCTION_EXPENDITURE         25.655977
# SUPPORT_SERVICES_EXPENDITURE    25.655977
# OTHER_EXPENDITURE               28.629738
# CAPITAL_OUTLAY_EXPENDITURE      25.655977
# GRADES_PK_G                     10.087464
# GRADES_KG_G                      4.839650
# GRADES_4_G                       4.839650
# GRADES_8_G                       4.839650
# GRADES_12_G                      4.839650
# GRADES_1_8_G                    40.524781
# GRADES_9_12_G                   37.551020
# GRADES_ALL_G                     4.839650
# AVG_MATH_4_SCORE                 0.000000
# ...

# %% [markdown]
# ## - You may have noticed that our data has a year column. For now, forget about the year data and assume that each observation was made in the same year. Consider how you can fill in missing values for each variable. Filling in the missing values with a value is meaningful for which variables and for which ones?
# >Columns with a low percentage of blank values can be mean by using the 'fillna ()' function.

# %%
print(df['GRADES_8_G'].mean())
df["GRADES_8_G"].fillna(df["GRADES_8_G"].mean(), inplace=True)
print(df['GRADES_8_G'].mean())
# Out:
# 68106.53737745098
# 68106.53737745078

# %%
df.isnull().sum()*100/df.shape[0]
# Out:
# PRIMARY_KEY                      0.000000
# STATE                            0.000000
# YEAR                             0.000000
# ENROLL                          28.629738
# TOTAL_REVENUE                   25.655977
# FEDERAL_REVENUE                 25.655977
# STATE_REVENUE                   25.655977
# LOCAL_REVENUE                   25.655977
# TOTAL_EXPENDITURE               25.655977
# INSTRUCTION_EXPENDITURE         25.655977
# SUPPORT_SERVICES_EXPENDITURE    25.655977
# OTHER_EXPENDITURE               28.629738
# CAPITAL_OUTLAY_EXPENDITURE      25.655977
# GRADES_PK_G                     10.087464
# GRADES_KG_G                      4.839650
# GRADES_4_G                       4.839650
# GRADES_8_G                       0.000000
# GRADES_12_G                      4.839650
# GRADES_1_8_G                    40.524781
# GRADES_9_12_G                   37.551020
# GRADES_ALL_G                     4.839650
# AVG_MATH_4_SCORE                 0.000000
# ...

# %% [markdown]
# ### Method 2

# %%
print(df['AVG_READING_4_SCORE'].mean())

states= df.AVG_READING_4_SCORE

for i in range(0, len(states)):
    if pd.isnull(states[i]):
        states[i] = states[i-1]
        
print(df['AVG_READING_4_SCORE'].mean())

# %% [markdown]
# ### Method 3

# %%
print(df['AVG_READING_8_SCORE'].mean())

df.AVG_READING_8_SCORE.interpolate(method='linear',inplace=True)
print(df['AVG_READING_8_SCORE'].mean())
# Out:
# 263.55871886120997
# 262.96096522356277

# %% [markdown]
# ## Now it's time to consider the factor of time! Review your answer in question 2 and fill in the missing data based on the values observed during that year. For example, if you want to fill a value with an average value, calculate the average of that year.

# %% [markdown]
# #### df.head(12)

# %%
states= df

# %%
for i in range(0, len(states)):
    if pd.isnull(states['TOTAL_REVENUE'][i]):
        states['TOTAL_REVENUE'][i]=df.groupby('YEAR').mean()["TOTAL_REVENUE"][states['YEAR'][i]]
states

print(df['TOTAL_REVENUE'].mean())
print(states['TOTAL_REVENUE'].mean())
# Out:
# 9097897.34263236
# 9097897.34263236

# %% [markdown]
#              print(states['AVG_READING_4_SCORE'][i])
#
#     states['AVG_READING_4_SCORE'][i] = (np.mean(states[(states.YEAR==states['YEAR'][i])].AVG_READING_8_SCORE))
