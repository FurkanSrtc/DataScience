# %% [markdown]
# What is the purpose the data exploration?

# %% [markdown]
# >It is the process of discovering data to gain access to the information hidden
# >in the data.

# %% [markdown]
# 2-Suppose you are working on a dataset containing customer reviews of an e-commerce company's products. Customer reviews collected through the company's website are rated between 1 and 5 depending on whether the content is positive or negative.
#
# 2-1-What kind of problems do you expect to encounter in this raw data?
# >We should be cautious about this interpretation, as we will see that some variables that appear as objects are actually numeric variables.
# >Data can return null
#
# 2-2-If your task is to identify the characteristics that reveal that the customers' comments are positive or negative, how would you do that and what methods would you use for this?
# >First, a list of negative words can be created. By comparing the words in the comment with negative words, comments containing negative words can be transferred >into a different dataframe. But 2 negative words can make the sentence positive. For this, the number and position of negative words in the sentence is important.
#
# 2-3-What are the useful features that can be extracted from raw data? How can you access this data and understand whether it is useful?
# >When we are given a data set, our ultimate goal would be something like this:
# >Forecasting house prices in the next month.
# >Predicting hesitant customers in the coming week.
# >Predicting tomorrow's electricity consumption and energy demand.
# >Creating a mobile application that can detect a person from a photo.
# >Implementing a recommendation system for a website that constantly broadcasts video
# >However, we need to analyze our data to find good features. We do this by analyzing the relationships between features and between features and target. This process >is called data discovery.
# >To get the most out of the data, we need to get rid of the irrelevant and potentially misleading parts of that data and turn the data into a form that we can easily work with.
# >For this, we have to do various analyzes.
# >First step Data clearing refers to the process of eliminating irrelevant or noisy values ​​that can lead us to misunderstand the data or the patterns we create on >them.
# >After clearing our data, we need to find useful features that could explain our goal. Target refers to the variable we are trying to explain in our dataset, while >the attribute refers to the variables used to describe the target. The process of finding and creating useful features is called feature engineering.

# %% [markdown]
# Why do you think missing values should be taking care of?
# >Missing values can distort the type of data, and some analyzes may not work when missing data.

# %% [markdown]
# Do you think that outliers have an impact on a dataset? If so, how would you explain this impact?
# >Outliers behave differently from other data models, and they increase the error with overfitting, so the outlier must be detected and some actions must be taken on it.
#
# ![image.png](attachment:0a26fbb0-c961-40dd-9229-b660d8c74777.png)

# %% [markdown]
# Please briefly summarize you first actions when you start analyzing the data?

# %% [markdown]
# >Data Cleaning
# >It is the first stage of the EDA process. We take the dataset and try to fix the problems we can detect in the data. Data cleaning includes these main steps:
# >
# >Removing unnecessary data and outliers.
# >Removing duplicates
# >Filling the missing values.
# >Exploring the data
# >This second step is investigating data to discover relationships between different features and patterns in the data. The main tools we use at this stage are statistics and visualization techniques. If we detect new problems in the data during the investigation, we go back to the cleaning stage and clear the data by eliminating the newly found problems.
# >
# >Feature engineering
# >The final step of EDA is feature engineering, where we select the most useful features or create new features from existing features. This phase takes us to the next steps of the data science pipeline. However, if we detect some data problems, we should apply to the data cleaning phase and clean the data again. Also, if we convert existing features or create new ones, we need to go back to the data discovery phase to test whether these new features are useful.
# >
# >Main steps taken throughout the data exploration process are as follows:
# >
# >Variable Identification.
# >Univariate Analysis.
# >Bi-variate Analysis.
# >Missing Values Treatment.
# >Outlier Treatment.
# >Variable Transformation.
# >Variable Creation.
# >Throughout this section, we review each stage step by step. Let's get started
